# %% [markdown]
# LSTM model with 7 feature ('Log_OC_Ratio', 'Log_HL_Ratio', 'Log_Vol_Change', 'SMA_10','RSI_14', 'ATR_14') + Financial News Sentiment
#
# Target: Log Returns

# %% [markdown]
# Importing all the necessary Libraries

# %%
# Standard library
import os
import random
from datetime import datetime, timedelta

# Data manipulation and numerical computing
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt

# Machine learning preprocessing and metrics
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import class_weight
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix

# TensorFlow and Keras
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout, LSTM
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau


import ta
from ta.trend import SMAIndicator
from ta.momentum import RSIIndicator
from ta.volatility import AverageTrueRange

# Financial data
import yfinance as yf

#Common Function
import sys
sys.path.append("C:\\FYP\\sxk1332\\Next Day Predictions")
import Common_Functions
import importlib

# %% [markdown]
# Removing randomness from the model to enforce consistent results

# %%
#Ensures hash-based operations (like in dicts, sets, or some internal functions) are reproducible across runs
os.environ['PYTHONHASHSEED'] = '0'  # For hash-based operations

#Using the same seed ensures any ranom operations like weight initalization or dropout are the same each time
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

#Tensorflow operations can be non-deterministic even with a fixed seed. This code forced TensorFlow to use deterministic algorithms
tf.config.experimental.enable_op_determinism()

# %%
#Loading the sentiment CSV file before passing it to the LSTM
sentiment_df = pd.read_csv("C:\\FYP\sxk1332\\Next Day Predictions\\daily_apple_news_sentiment.csv")

#Converts the date column into a proper datetime object
sentiment_df["date"] = pd.to_datetime(sentiment_df["date"])

# %% [markdown]
# Function to fetch and download data (Apple Stock Price) from Yahoo everyday roughly for the past 10 years

# %%
ticker = 'AAPL'  
data = yf.download(ticker, start="2015-01-01")

#When you first download stock data using yf.download() the resulting dataframe uses date as the index (row labels)
#Here we are moving date from the index into a regular column - this allows you to extract the dates
data.reset_index(inplace=True)

# Flatten the column names if they're MultiIndex
if isinstance(data.columns, pd.MultiIndex):
    data.columns = data.columns.get_level_values(0)

#Calculating Ratios from Stationary Price Features
data['Log_OC_Ratio'] = np.log(data['Close'] / data['Open'])
data['Log_HL_Ratio'] = np.log(data['High'] / data['Low'])
data['Log_Vol_Change'] = np.log(data['Volume'] / data['Volume'].shift(1))

#Trend Indicator
sma10 = SMAIndicator(data['Close'], window=10).sma_indicator()
data['SMA_10'] = data['Close'] / sma10

#Momentum Indicator
data['RSI_14'] = RSIIndicator(data['Close'], window=14).rsi()

#Volatility Indicator
atr_val = AverageTrueRange(data['High'], data['Low'], data['Close'], window=14).average_true_range()
data['ATR_14'] = atr_val / data['Close']

#data.to_csv("Before.csv", index=False)

#Merge sentiment with stock data using left join (add sentiment data where available)
data = data.merge(
    sentiment_df,
    left_on="Date",
    right_on="date",
    how="left"
)

#Add a new column to the original dataframe 
#Not all days have a sentiment value so add a 0 for all missing sentiment days
data["avg_sentiment"] = data["avg_sentiment"].fillna(0)

#The model cannot differentiate between 0 being a sentiment score and 0 being no news 
#so adding a binary column that gives the model context to only look at days with news

#A binary feature that tells the model whether news exists that day
data["has_news"] = (data["avg_sentiment"] != 0).astype(int)

data.replace([np.inf, -np.inf], np.nan, inplace=True)
data.fillna(method='ffill', inplace=True) 
data.dropna(inplace=True)  

#Create a dataframe for tomorrows predictions 
data_for_prediction = data.copy()

#Create a dataframe for training only
train_df = data.copy()

train_df['Returns'] = train_df['Close'].pct_change()

#Convert returns into a direction
train_df['Target'] = (train_df['Returns'].shift(-1) > 0).astype(int)

train_df = train_df.iloc[:-1].reset_index(drop=True)

#train_df.to_csv("After.csv", index=False)

#Define feature 
price_features  = ['Log_OC_Ratio', 'Log_HL_Ratio', 'Log_Vol_Change', 'SMA_10', 'RSI_14', 'ATR_14']
sentiment_features  = ['avg_sentiment', 'has_news']

#Extract specific columns from your DataFrame and converts them into a NumPy array.
price_data = train_df[price_features].values
sentiment_data = train_df[sentiment_features].values
target_data = train_df['Target'].values
datetime_index = train_df['Date'].values
# Out:
# C:\Users\Sxk1332\AppData\Local\Temp\ipykernel_30596\2472693583.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start="2015-01-01", end = '2026-03-16')
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Sxk1332\AppData\Local\Temp\ipykernel_30596\2472693583.py:49: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)

# %%
# Get the number of close prices
print(f"Number of close prices: {len(train_df)}")
# Out:
# Number of close prices: 2801

# %% [markdown]
# Splitting the data into a training set (first 85%) and testing set (remaining 15%)

# %%
#Defining the split size
#70% of the total data to be used for training, 15% for validation, and 15% for testing
total_size = len(train_df)
train_size = int(len(train_df) * 0.70)
val_size = int(len(train_df) * 0.15)

#Chronogically splitting the data so first 70% is training, the next 15% is validation and the remaining 15% is testing
train_price = price_data[:train_size]
val_price = price_data[train_size:train_size + val_size]
test_price = price_data[train_size + val_size:]

#Split Sentiment Data (bianry range so no scaling needed)
train_sent = sentiment_data[:train_size]
val_sent = sentiment_data[train_size:train_size + val_size]
test_sent = sentiment_data[train_size + val_size:]

#Split the Traget (no scaling)
train_y = target_data[:train_size]
val_y   = target_data[train_size:train_size+val_size]
test_y  = target_data[train_size+val_size:]

print("Total samples:", total_size)

print("\nDataset sizes:")
print(f"Training set   : {len(train_y)} samples ({len(train_y)/total_size:.2%})")
print(f"Validation set : {len(val_y)} samples ({len(val_y)/total_size:.2%})")
print(f"Test set       : {len(test_y)} samples ({len(test_y)/total_size:.2%})")

print("Train:", train_y.shape)
print("Val  :", val_y.shape)
print("Test :", test_y.shape)

print("\nCheck sum:", len(train_y) + len(val_y) + len(test_y))
# Out:
# Total samples: 2801
#
# Dataset sizes:
# Training set   : 1960 samples (69.98%)
# Validation set : 420 samples (14.99%)
# Test set       : 421 samples (15.03%)
# Train: (1960,)
# Val  : (420,)
# Test : (421,)
#
# Check sum: 2801

# %% [markdown]
# Normalizing the price features using a Standard Scaler. But only using only the training data as the scaler to prevent data leaks.

# %%
#We are now scaling the data feature wise to ensure all features contribute meaningfully
num_features = train_price.shape[1]
scalers = [StandardScaler() for _ in range(num_features)]

#Fit scalers on training data only
for i, scaler in enumerate(scalers):
    scaler.fit(train_price[:, [i]])

#Function to scale data using all scalers
def scale_data(data, scalers):
    return np.hstack([scalers[i].transform(data[:, [i]]) for i in range(len(scalers))])

#Transform all splits
train_price_scaled = scale_data(train_price, scalers)
val_price_scaled = scale_data(val_price, scalers)
test_price_scaled = scale_data(test_price, scalers)

# Training data Mean should be ~0 and Std Dev should be ~1
print(f"Train Scaled -> Mean: {train_price_scaled.mean():.4f}, Std Dev: {train_price_scaled.std():.4f}")
# Val/Test will vary slightly, which is expected
print(f"Val   Scaled -> Mean: {val_price_scaled.mean():.4f}, Std Dev: {val_price_scaled.std():.4f}")
print(f"Test  Scaled -> Mean: {test_price_scaled.mean():.4f}, Std Dev: {test_price_scaled.std():.4f}")
# Out:
# Train Scaled -> Mean: 0.0000, Std Dev: 1.0000
# Val   Scaled -> Mean: -0.0772, Std Dev: 0.8611
# Test  Scaled -> Mean: -0.0154, Std Dev: 1.0238

# %%
#Stack scaled prices with unscaled sentiment
train_final = np.hstack([train_price_scaled, train_sent])
val_final = np.hstack([val_price_scaled, val_sent])
test_final = np.hstack([test_price_scaled, test_sent])

all_cols = price_features + sentiment_features

datasets = {
    "Train": train_final,
    "Validation": val_final,
    "Test": test_final
}

#Loop through the dictionary items
for name, dataset_array in datasets.items():
    rows, cols = dataset_array.shape
    print(f"{name} Set - Rows: {rows}, Columns: {cols}")
# Out:
# Train Set - Rows: 1960, Columns: 8
# Validation Set - Rows: 420, Columns: 8
# Test Set - Rows: 421, Columns: 8

# %% [markdown]
# Creating a Sliding Window to prepare the input data for the LSTM model

# %%
def create_multifeature_dataset_with_context(feature_data, target_data, time_step, prev_features=None):
    #Handling context for the validation and test set (stacking the last 24 days from the previous set to the current set)
    if prev_features is not None:
        feature_data = np.vstack([prev_features[-(time_step - 1):], feature_data])
    
    X, y = [] , []
    
    for i in range(time_step - 1, len(feature_data)):
        window = feature_data[i - (time_step - 1) : i + 1] #here we grab all columns and rows per timesteps (rows 0-24 first time)
        X.append(window)
        
        if prev_features is not None:
            y_idx = i - (time_step - 1) #here we predict the target for row 25

        #For the validation and test set we stacked the last 24 days from the previous set to the current set 
        #so to ensure the target (first index in the validation or test set) is aligned we need to use index 24
        else:
            y_idx = i  
            
        if y_idx < len(target_data):
            y.append(target_data[y_idx])
    
    return np.array(X), np.array(y)

time_step = 25

X_train, y_train = create_multifeature_dataset_with_context(train_final, train_y, time_step)

X_val, y_val = create_multifeature_dataset_with_context(val_final, val_y, time_step, prev_features=train_final)

X_test, y_test = create_multifeature_dataset_with_context(test_final, test_y, time_step, prev_features=val_final)

# Check shapes
print("Shapes of the datasets:")
print(f"X_train: {X_train.shape}, y_train: {y_train.shape}")
print(f"X_val  : {X_val.shape}, y_val  : {y_val.shape}")
print(f"X_test : {X_test.shape}, y_test : {y_test.shape}")
# Out:
# Shapes of the datasets:
# X_train: (1936, 25, 8), y_train: (1936,)
# X_val  : (420, 25, 8), y_val  : (420,)
# X_test : (421, 25, 8), y_test : (421,)

# %% [markdown]
# Here we add class wights - Apple's stock has more ups than downs
# So penalise the model more (with a larger weight) so missing down days

# %%
#Check the raw counts of Up (1) vs Down (0)
classes, counts = np.unique(y_train, return_counts=True)
class_counts = dict(zip(classes, counts))

print("--- Data Distribution ---")
print(f"Down moves (0): {class_counts.get(0, 0)}")
print(f"Up moves (1):   {class_counts.get(1, 0)}")

#Calculate the weights
weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)
class_weights_dict = {int(classes[i]): weights[i] for i in range(len(weights))}

print("\n--- Calculated Weights ---")
for cls, weight in class_weights_dict.items():
    label = "Up" if cls == 1 else "Down"
    print(f"{label} (Class {cls}): {weight:.4f}")
# Out:
# --- Data Distribution ---
# Down moves (0): 922
# Up moves (1):   1014
#
# --- Calculated Weights ---
# Down (Class 0): 1.0499
# Up (Class 1): 0.9546

# %% [markdown]
# Building and Training the model

# %%
model = Sequential()

#Build the model

#layer 1
model.add(Input(shape=(X_train.shape[1], X_train.shape[2])))
model.add((LSTM(units=32, return_sequences=True, kernel_regularizer=l2(0.002))))
model.add(Dropout(0.25))
model.add((LSTM(units=32, return_sequences=False, kernel_regularizer=l2(0.002))))
model.add(Dropout(0.25))

#Used a sigmoid function here, so the model is learning is the probability of of up or down higher 
model.add(Dense(units=1, activation='sigmoid'))

#compile the model
model.compile(optimizer=Adam(learning_rate=3e-4), loss='binary_crossentropy', metrics=['accuracy', 'precision', 'recall'])

#Train the model
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,          
    patience=5,          
    verbose=1,  
    min_lr=1e-6         
)

callbacks = [early_stop, reduce_lr]

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val), 
    epochs=150,
    batch_size=32,
    class_weight=class_weights_dict,
    shuffle=False,
    callbacks=callbacks,
    verbose=2
)

test_loss, test_accuracy, test_precision, test_recall = model.evaluate(X_test, y_test)
print(f"Test Loss (binary crossentropy): {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test Precision: {test_precision:.4f}")
print(f"Test Recall:    {test_recall:.4f}")
# Out:
# Epoch 1/150
# 61/61 - 7s - 113ms/step - accuracy: 0.4881 - loss: 0.8187 - precision: 0.5127 - recall: 0.4576 - val_accuracy: 0.4976 - val_loss: 0.8035 - val_precision: 0.5249 - val_recall: 0.6991 - learning_rate: 3.0000e-04
# Epoch 2/150
# 61/61 - 1s - 17ms/step - accuracy: 0.4871 - loss: 0.7958 - precision: 0.5096 - recall: 0.5473 - val_accuracy: 0.5071 - val_loss: 0.7830 - val_precision: 0.5304 - val_recall: 0.7345 - learning_rate: 3.0000e-04
# Epoch 3/150
# 61/61 - 1s - 19ms/step - accuracy: 0.5072 - loss: 0.7772 - precision: 0.5274 - recall: 0.5690 - val_accuracy: 0.5167 - val_loss: 0.7674 - val_precision: 0.5380 - val_recall: 0.7212 - learning_rate: 3.0000e-04
# Epoch 4/150
# 61/61 - 1s - 17ms/step - accuracy: 0.5103 - loss: 0.7626 - precision: 0.5281 - recall: 0.6114 - val_accuracy: 0.5310 - val_loss: 0.7547 - val_precision: 0.5457 - val_recall: 0.7655 - learning_rate: 3.0000e-04
# Epoch 5/150
# 61/61 - 1s - 16ms/step - accuracy: 0.5160 - loss: 0.7501 - precision: 0.5331 - recall: 0.6114 - val_accuracy: 0.5333 - val_loss: 0.7449 - val_precision: 0.5497 - val_recall: 0.7345 - learning_rate: 3.0000e-04
# Epoch 6/150
# 61/61 - 1s - 20ms/step - accuracy: 0.5186 - loss: 0.7417 - precision: 0.5382 - recall: 0.5700 - val_accuracy: 0.5310 - val_loss: 0.7369 - val_precision: 0.5505 - val_recall: 0.6991 - learning_rate: 3.0000e-04
# Epoch 7/150
# 61/61 - 1s - 17ms/step - accuracy: 0.5145 - loss: 0.7347 - precision: 0.5345 - recall: 0.5661 - val_accuracy: 0.5357 - val_loss: 0.7303 - val_precision: 0.5518 - val_recall: 0.7301 - learning_rate: 3.0000e-04
# Epoch 8/150
# 61/61 - 1s - 17ms/step - accuracy: 0.4933 - loss: 0.7303 - precision: 0.5148 - recall: 0.5671 - val_accuracy: 0.5286 - val_loss: 0.7253 - val_precision: 0.5500 - val_recall: 0.6814 - learning_rate: 3.0000e-04
# Epoch 9/150
# 61/61 - 1s - 17ms/step - accuracy: 0.5186 - loss: 0.7244 - precision: 0.5394 - recall: 0.5533 - val_accuracy: 0.5071 - val_loss: 0.7215 - val_precision: 0.5373 - val_recall: 0.6062 - learning_rate: 3.0000e-04
# Epoch 10/150
# 61/61 - 1s - 16ms/step - accuracy: 0.5052 - loss: 0.7210 - precision: 0.5270 - recall: 0.5394 - val_accuracy: 0.5190 - val_loss: 0.7178 - val_precision: 0.5451 - val_recall: 0.6416 - learning_rate: 3.0000e-04
# Epoch 11/150
# 61/61 - 1s - 20ms/step - accuracy: 0.5176 - loss: 0.7177 - precision: 0.5403 - recall: 0.5286 - val_accuracy: 0.5357 - val_loss: 0.7152 - val_precision: 0.5677 - val_recall: 0.5752 - learning_rate: 3.0000e-04
# Epoch 12/150
# 61/61 - 1s - 20ms/step - accuracy: 0.5139 - loss: 0.7149 - precision: 0.5377 - recall: 0.5128 - val_accuracy: 0.5262 - val_loss: 0.7129 - val_precision: 0.5529 - val_recall: 0.6239 - learning_rate: 3.0000e-04
# Epoch 13/150
# 61/61 - 1s - 17ms/step - accuracy: 0.5310 - loss: 0.7121 - precision: 0.5502 - recall: 0.5730 - val_accuracy: 0.5000 - val_loss: 0.7112 - val_precision: 0.5299 - val_recall: 0.6283 - learning_rate: 3.0000e-04
# Epoch 14/150
# 61/61 - 1s - 19ms/step - accuracy: 0.5212 - loss: 0.7113 - precision: 0.5399 - recall: 0.5799 - val_accuracy: 0.5190 - val_loss: 0.7096 - val_precision: 0.5469 - val_recall: 0.6195 - learning_rate: 3.0000e-04
# Epoch 15/150
# 61/61 - 1s - 19ms/step - accuracy: 0.5258 - loss: 0.7090 - precision: 0.5456 - recall: 0.5661 - val_accuracy: 0.5262 - val_loss: 0.7081 - val_precision: 0.5509 - val_recall: 0.6460 - learning_rate: 3.0000e-04
# Epoch 16/150
# 61/61 - 1s - 20ms/step - accuracy: 0.5201 - loss: 0.7089 - precision: 0.5431 - recall: 0.5286 - val_accuracy: 0.5381 - val_loss: 0.7069 - val_precision: 0.5615 - val_recall: 0.6460 - learning_rate: 3.0000e-04
# Epoch 17/150
# 61/61 - 1s - 19ms/step - accuracy: 0.5155 - loss: 0.7072 - precision: 0.5385 - recall: 0.5247 - val_accuracy: 0.5548 - val_loss: 0.7063 - val_precision: 0.5816 - val_recall: 0.6150 - learning_rate: 3.0000e-04
# Epoch 18/150
# 61/61 - 1s - 19ms/step - accuracy: 0.5248 - loss: 0.7063 - precision: 0.5489 - recall: 0.5207 - val_accuracy: 0.5429 - val_loss: 0.7055 - val_precision: 0.5739 - val_recall: 0.5841 - learning_rate: 3.0000e-04
# Epoch 19/150
# 61/61 - 1s - 18ms/step - accuracy: 0.5294 - loss: 0.7055 - precision: 0.5514 - recall: 0.5444 - val_accuracy: 0.5476 - val_loss: 0.7041 - val_precision: 0.5776 - val_recall: 0.5929 - learning_rate: 3.0000e-04
# Epoch 20/150
# 61/61 - 1s - 21ms/step - accuracy: 0.5331 - loss: 0.7038 - precision: 0.5537 - recall: 0.5592 - val_accuracy: 0.5476 - val_loss: 0.7032 - val_precision: 0.5677 - val_recall: 0.6681 - learning_rate: 3.0000e-04
# Epoch 21/150
# 61/61 - 1s - 23ms/step - accuracy: 0.5351 - loss: 0.7028 - precision: 0.5569 - recall: 0.5503 - val_accuracy: 0.5476 - val_loss: 0.7036 - val_precision: 0.5763 - val_recall: 0.6018 - learning_rate: 3.0000e-04
# Epoch 22/150
# 61/61 - 2s - 28ms/step - accuracy: 0.5248 - loss: 0.7019 - precision: 0.5499 - recall: 0.5108 - val_accuracy: 0.5357 - val_loss: 0.7027 - val_precision: 0.5603 - val_recall: 0.6372 - learning_rate: 3.0000e-04
# Epoch 23/150
# 61/61 - 2s - 29ms/step - accuracy: 0.5258 - loss: 0.7019 - precision: 0.5502 - recall: 0.5187 - val_accuracy: 0.5381 - val_loss: 0.7022 - val_precision: 0.5597 - val_recall: 0.6637 - learning_rate: 3.0000e-04
# Epoch 24/150
# 61/61 - 2s - 26ms/step - accuracy: 0.5232 - loss: 0.7013 - precision: 0.5447 - recall: 0.5464 - val_accuracy: 0.5429 - val_loss: 0.7021 - val_precision: 0.5649 - val_recall: 0.6549 - learning_rate: 3.0000e-04
# Epoch 25/150
# 61/61 - 1s - 20ms/step - accuracy: 0.5408 - loss: 0.6998 - precision: 0.5638 - recall: 0.5444 - val_accuracy: 0.5452 - val_loss: 0.7018 - val_precision: 0.5655 - val_recall: 0.6681 - learning_rate: 3.0000e-04
# Epoch 26/150
# 61/61 - 1s - 19ms/step - accuracy: 0.5176 - loss: 0.7011 - precision: 0.5427 - recall: 0.5010 - val_accuracy: 0.5405 - val_loss: 0.7014 - val_precision: 0.5637 - val_recall: 0.6460 - learning_rate: 3.0000e-04
# Epoch 27/150
# 61/61 - 1s - 20ms/step - accuracy: 0.5258 - loss: 0.6995 - precision: 0.5499 - recall: 0.5217 - val_accuracy: 0.5310 - val_loss: 0.7011 - val_precision: 0.5520 - val_recall: 0.6814 - learning_rate: 3.0000e-04
# Epoch 28/150
# 61/61 - 1s - 19ms/step - accuracy: 0.5351 - loss: 0.6991 - precision: 0.5606 - recall: 0.5197 - val_accuracy: 0.5310 - val_loss: 0.7019 - val_precision: 0.5539 - val_recall: 0.6593 - learning_rate: 3.0000e-04
# Epoch 29/150
# 61/61 - 1s - 17ms/step - accuracy: 0.5294 - loss: 0.6984 - precision: 0.5522 - recall: 0.5375 - val_accuracy: 0.5262 - val_loss: 0.7015 - val_precision: 0.5477 - val_recall: 0.6858 - learning_rate: 3.0000e-04
# Epoch 30/150
# 61/61 - 1s - 18ms/step - accuracy: 0.5207 - loss: 0.6993 - precision: 0.5436 - recall: 0.5286 - val_accuracy: 0.5429 - val_loss: 0.7012 - val_precision: 0.5590 - val_recall: 0.7124 - learning_rate: 3.0000e-04
# Epoch 31/150
# 61/61 - 1s - 17ms/step - accuracy: 0.5424 - loss: 0.6970 - precision: 0.5660 - recall: 0.5414 - val_accuracy: 0.5405 - val_loss: 0.7014 - val_precision: 0.5600 - val_recall: 0.6814 - learning_rate: 3.0000e-04
# Epoch 32/150
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 6.000000284984708e-05.
# 61/61 - 1s - 16ms/step - accuracy: 0.5418 - loss: 0.6969 - precision: 0.5653 - recall: 0.5424 - val_accuracy: 0.5476 - val_loss: 0.7014 - val_precision: 0.5612 - val_recall: 0.7301 - learning_rate: 3.0000e-04
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5178 - loss: 0.7096 - precision: 0.5481 - recall: 0.5796
# Test Loss (binary crossentropy): 0.7096
# Test Accuracy: 0.5178
# Test Precision: 0.5481
# Test Recall:    0.5796

# %%
# Plot Loss
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training vs Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.show()

# %% [markdown]
# Predictions

# %%
#Get probabilities
y_pred_probs = model.predict(X_test)

#Convert to binary direction (1 if prob > 0.5, else 0)
y_pred = (y_pred_probs > 0.5).astype(int)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print(f"Accuracy : {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step
# Accuracy : 0.5178
# Precision: 0.5481
# Recall   : 0.5796

# %% [markdown]
# Using the model to predict the direction of tomorrow:

# %%
#Extract the raw feature values from the un-truncated dataframe
price_data_live = data_for_prediction[price_features].values
sentiment_data_live = data_for_prediction[sentiment_features].values

#Scale the price features using the fitted scalers from training
full_price_scaled = scale_data(price_data_live, scalers)

#Combine scaled price features with sentiment features
full_final_live = np.hstack([full_price_scaled, sentiment_data_live])

# %%
#Extract the last 25 days for tomorrows prediction
last_window = full_final_live[-time_step:]

# Reshape for LSTM input: (samples, time_steps, features)
X_live = np.reshape(last_window, (1, time_step, full_final_live.shape[1]))

print("Dates and Close Prices used for the prediction window (last {} days):".format(time_step))

# Slice the last 'time_step' rows of the dataframe to get matching dates and prices
prediction_window_df = data_for_prediction.iloc[-time_step:]

for idx, (row_idx, row) in enumerate(prediction_window_df.iterrows()):
    print(f"Day {idx+1:2d} | Date: {row['Date'].date()} | Close Price: {row['Close']:.2f}")

# Specifically highlight the final day (today's close)
print("-" * 50)
print(f"Final Close Price used (Today): {prediction_window_df['Close'].iloc[-1]:.2f}")
# Out:
# Dates and Close Prices used for the prediction window (last 25 days):
# Day  1 | Date: 2026-02-06 | Close Price: 277.86
# Day  2 | Date: 2026-02-09 | Close Price: 274.62
# Day  3 | Date: 2026-02-10 | Close Price: 273.68
# Day  4 | Date: 2026-02-11 | Close Price: 275.50
# Day  5 | Date: 2026-02-12 | Close Price: 261.73
# Day  6 | Date: 2026-02-13 | Close Price: 255.78
# Day  7 | Date: 2026-02-17 | Close Price: 263.88
# Day  8 | Date: 2026-02-18 | Close Price: 264.35
# Day  9 | Date: 2026-02-19 | Close Price: 260.58
# Day 10 | Date: 2026-02-20 | Close Price: 264.58
# Day 11 | Date: 2026-02-23 | Close Price: 266.18
# Day 12 | Date: 2026-02-24 | Close Price: 272.14
# Day 13 | Date: 2026-02-25 | Close Price: 274.23
# Day 14 | Date: 2026-02-26 | Close Price: 272.95
# Day 15 | Date: 2026-02-27 | Close Price: 264.18
# Day 16 | Date: 2026-03-02 | Close Price: 264.72
# Day 17 | Date: 2026-03-03 | Close Price: 263.75
# Day 18 | Date: 2026-03-04 | Close Price: 262.52
# Day 19 | Date: 2026-03-05 | Close Price: 260.29
# Day 20 | Date: 2026-03-06 | Close Price: 257.46
# Day 21 | Date: 2026-03-09 | Close Price: 259.88
# Day 22 | Date: 2026-03-10 | Close Price: 260.83
# Day 23 | Date: 2026-03-11 | Close Price: 260.81
# Day 24 | Date: 2026-03-12 | Close Price: 255.76
# Day 25 | Date: 2026-03-13 | Close Price: 250.12
# --------------------------------------------------
# Final Close Price used (Today): 250.12

# %%
#Generate the prediction probability
prediction_prob = model.predict(X_live)[0][0]
FinalPrediction = ""

#Output the results
last_date = data_for_prediction['Date'].iloc[-1]
prediction_date = last_date + pd.offsets.BDay(1)

print(f"Latest data used for prediction: {last_date.date()}")
print(f"Predicting direction for: {prediction_date.date()}")
print(f"Probability of 'UP' move: {prediction_prob:.4f}")

if prediction_prob > 0.51:
    print("Final Prediction: UP")
    FinalPrediction= "UP"
else:
    print("Final Prediction: DOWN")
    FinalPrediction= "DOWN"
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Latest data used for prediction: 2026-03-13
# Predicting direction for: 2026-03-16
# Probability of 'UP' move: 0.5367
# Final Prediction: UP

# %%
importlib.reload(Common_Functions)

Common_Functions.WriteToDatabase("Update",prediction_date,"LSTM_Returns_Direction",str(FinalPrediction))
print("Data Sucessfully Saved")
# Out:
# Data Sucessfully Saved
